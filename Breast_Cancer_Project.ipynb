# %% [markdown]
# # Imports (Run these):

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Download data
# !gdown https://drive.google.com/uc?id=1r_T3NuNK6aUo0l5O7WKcjCy5Oia7gQfn
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1r_T3NuNK6aUo0l5O7WKcjCy5Oia7gQfn
# To: /content/Breast_cancer_data.csv
# 100% 19.7k/19.7k [00:00<00:00, 32.7MB/s]

# %%
# Convert to dataframe
data = pd.read_csv('/content/Breast_cancer_data.csv')

# %%
# Explore data
data
# Out:
#      mean_radius  mean_texture  mean_perimeter  mean_area  mean_smoothness  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
#      diagnosis
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0
# ..         ...
# 564          0
# 565          0
# 566          0
# 567          0
# 568          1
#
# [569 rows x 6 columns]

# %% [markdown]
# # Splits (Run this):

# %%
from sklearn.model_selection import train_test_split
y = data['diagnosis']
X = data.drop('diagnosis', axis = 1)
# Create test/train splits
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state = 42)

# %% [markdown]
# # Train/Test Models (Logistic Regression, knn):

# %%
# Imports
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier

# %%
lr = LogisticRegression().fit(X_train, y_train)
lr.score(X_test, y_test)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.9361702127659575

# %%
knn = KNeighborsClassifier(n_neighbors=3).fit(X_train, y_train)
knn.score(X_test, y_test)
# Out:
# 0.9095744680851063
